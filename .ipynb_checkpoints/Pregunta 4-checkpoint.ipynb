# %%
import pandas as pd
import numpy as np
import seaborn as sn
from keras.models import Sequential
from keras.layers import Dense,SimpleRNN, Conv1D, Flatten
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 4. CNN *vs* RNN Prediciendo el Ozono Atmosférico

# %% [markdown]
# **a)**

# %%
data = pd.read_csv('./ozone_data.csv') 
data_train, data_val, data_test = np.split(data.sample(frac=1), [int(.6*len(data)), int(.8*len(data))])

# %%
data_train_o3= data_train[["registered_on","O3"]].sort_index()
data_val_o3= data_val[["registered_on", "O3"]].sort_index()
data_test_o3= data_test[["registered_on","O3"]].sort_index()

# %%
X_train = data_train.values[:,1:]
X_test = data_test_o3.values[:,1:]
X_val = data_val_o3.values[:,1:]

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
scaler.fit(X_val)
X_val_scaled = scaler.transform(X_val)
scaler.fit(X_test)
X_test_scaled = scaler.transform(X_test)

# %%
plt.subplots(figsize = (12,12))
sn.heatmap(data.corr())

# %% [markdown]
# **b)**

# %%
def create_dataset(dataset,lag=1):
    dataX = []
    dataY = []
    dataset = dataset.flatten()
    for i in range(lag+1, len(dataset)):
        dataX.append(dataset[i-(lag+1):i-1])
        dataY.append(dataset[i])
    return np.array(dataX),np.array(dataY)

# %%
lag = 3
trainX, trainY = create_dataset(X_train_scaled, lag)
testX, testY = create_dataset(X_test_scaled, lag)
valX, valY = create_dataset(X_val_scaled, lag)

# %% [markdown]
# **c)**

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
#valX = np.reshape(valX, (valX.shape[0], 1, valX.shape[1]))

# %%
model_rnn = Sequential()
model_rnn.add(SimpleRNN(units=4, input_shape=(1,lag), activation='tanh',return_sequences=False,go_backwards=False))
model_rnn.add(Dense(1,activation='linear'))
model_rnn.compile(loss='mean_squared_error', optimizer='adam')
model_rnn.summary()
rnn_weights = model_rnn.get_weights()
hist_rnn = model_rnn.fit(trainX, trainY, epochs=25, batch_size=1, verbose=1)
# Out:
# WARNING:tensorflow:From /home/fran/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 4)                 32
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 37
# Trainable params: 37
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/fran/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/25
# 11720/11720 [==============================] - 15s 1ms/step - loss: 1.0285
# Epoch 2/25
# 11720/11720 [==============================] - 23s 2ms/step - loss: 0.9835
# Epoch 3/25
# 11720/11720 [==============================] - 15s 1ms/step - loss: 0.9809
# Epoch 4/25
# 11720/11720 [==============================] - 15s 1ms/step - loss: 0.9795
# Epoch 5/25
# 11720/11720 [==============================] - 15s 1ms/step - loss: 0.9792
# Epoch 6/25
# 11720/11720 [==============================] - 20s 2ms/step - loss: 0.9789
# Epoch 7/25
# 11720/11720 [==============================] - 13s 1ms/step - loss: 0.9788
# Epoch 8/25
# 11720/11720 [==============================] - 20s 2ms/step - loss: 0.9790
# Epoch 9/25
# 11720/11720 [==============================] - 20s 2ms/step - loss: 0.9788
# Epoch 10/25
# 11720/11720 [==============================] - 21s 2ms/step - loss: 0.9768
# Epoch 11/25
# 11720/11720 [==============================] - 20s 2ms/step - loss: 0.9770
# Epoch 12/25
# 11720/11720 [==============================] - 19s 2ms/step - loss: 0.9777
# Epoch 13/25
# 11720/11720 [==============================] - 20s 2ms/step - loss: 0.9778
# Epoch 14/25
# 11720/11720 [==============================] - 19s 2ms/step - loss: 0.9772
# Epoch 15/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9777
# Epoch 16/25
# 11720/11720 [==============================] - 14s 1ms/step - loss: 0.9774
# Epoch 17/25
# 11720/11720 [==============================] - 14s 1ms/step - loss: 0.9773
# Epoch 18/25
# 11720/11720 [==============================] - 13s 1ms/step - loss: 0.9771
# Epoch 19/25
# 11720/11720 [==============================] - 12s 1ms/step - loss: 0.9771
# Epoch 20/25
# 11720/11720 [==============================] - 13s 1ms/step - loss: 0.9762
# Epoch 21/25
# 11720/11720 [==============================] - 13s 1ms/step - loss: 0.9762
# Epoch 22/25
# 11720/11720 [==============================] - 12s 1ms/step - loss: 0.9765
# Epoch 23/25
# 11720/11720 [==============================] - 13s 1ms/step - loss: 0.9758
# Epoch 24/25
# 11720/11720 [==============================] - 12s 1ms/step - loss: 0.9767
# Epoch 25/25
# 11720/11720 [==============================] - 12s 1ms/step - loss: 0.9769

# %%
listaloss_rnn  = []
for i in range(25):
    listaloss_rnn.append(hist_rnn.history['loss'][i])

plt.plot(range(26)[1:],listaloss_rnn,label='loss', linewidth=2)

plt.legend(['loss_rnn'])
plt.ylabel('MSE')
plt.xlabel('epochs')
plt.grid(1)
plt.show()

# %%
model_cnn = Sequential()
model_cnn.add(Conv1D(4, kernel_size=1,input_shape=(1,lag), activation='relu',padding='valid')) 
model_cnn.add(Flatten())
model_cnn.add(Dense(1,activation='linear'))
model_cnn.compile(loss='mean_squared_error', optimizer='adam')
model_cnn.summary()
cnn_weights = model_cnn.get_weights()
hist_cnn = model_cnn.fit(trainX, trainY, epochs=25, batch_size=1, verbose=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 1, 4)              16
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 11720/11720 [==============================] - 21s 2ms/step - loss: 1.1593
# Epoch 2/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9899
# Epoch 3/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9825
# Epoch 4/25
# 11720/11720 [==============================] - 17s 1ms/step - loss: 0.9813
# Epoch 5/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9819
# Epoch 6/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9814
# Epoch 7/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9808
# Epoch 8/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9798
# Epoch 9/25
# 11720/11720 [==============================] - 18s 2ms/step - loss: 0.9810
# Epoch 10/25
# 11720/11720 [==============================] - 17s 1ms/step - loss: 0.9804
# Epoch 11/25
# 11720/11720 [==============================] - 17s 1ms/step - loss: 0.9804
# Epoch 12/25
# 11720/11720 [==============================] - 17s 1ms/step - loss: 0.9800
# Epoch 13/25
# 11720/11720 [==============================] - 17s 1ms/step - loss: 0.9799
# Epoch 14/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9813
# Epoch 15/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9801
# Epoch 16/25
# 11720/11720 [==============================] - 15s 1ms/step - loss: 0.9804
# Epoch 17/25
# 11720/11720 [==============================] - 18s 2ms/step - loss: 0.9806
# Epoch 18/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9808
# Epoch 19/25
# 11720/11720 [==============================] - 17s 1ms/step - loss: 0.9809
# Epoch 20/25
# 11720/11720 [==============================] - 17s 1ms/step - loss: 0.9785
# Epoch 21/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9808
# Epoch 22/25
# 11720/11720 [==============================] - 17s 1ms/step - loss: 0.9802
# Epoch 23/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9801
# Epoch 24/25
# 11720/11720 [==============================] - 17s 1ms/step - loss: 0.9799
# Epoch 25/25
# 11720/11720 [==============================] - 16s 1ms/step - loss: 0.9790

# %%
listaloss_cnn  = []
for i in range(25):
    listaloss_cnn.append(hist_cnn.history['loss'][i])

plt.plot(range(26)[1:],listaloss_cnn,label='loss', linewidth=2)

plt.legend(['loss_cnn'])
plt.ylabel('MSE')
plt.xlabel('epochs')
plt.grid(1)
plt.show()

# %% [markdown]
# El tamaño del kernel en la red convolucional y el tamaño del shape en la recurrente debe ser menor al tamaño del shape de la variable de entrada.

# %% [markdown]
# **d)**

# %%
trainPredict_rnn = model_rnn.predict(trainX,batch_size=1)
trainPredict_rnn = scaler.inverse_transform(trainPredict_rnn)

trainY_rnn = scaler.inverse_transform(trainY)

testPredict_rnn = model_rnn.predict(testX,batch_size=1)
testPredict_rnn = scaler.inverse_transform(testPredict_rnn)

testY_rnn = scaler.inverse_transform(testY)

# %%
trainScore_rnn = np.sqrt(mean_squared_error(trainY_rnn, trainPredict_rnn))
print('Train Score: %.2f RMSE' % (trainScore_rnn))
testScore_rnn = np.sqrt(mean_squared_error(testY_rnn, testPredict_rnn))
print('Test Score: %.2f RMSE' % (testScore_rnn))
# Out:
# Train Score: 0.12 RMSE
# Test Score: 0.12 RMSE

# %%
trainPredict_cnn = model_cnn.predict(trainX,batch_size=1)
trainPredict_cnn = scaler.inverse_transform(trainPredict_cnn)

trainY_cnn = scaler.inverse_transform(trainY)

testPredict_cnn = model_cnn.predict(testX,batch_size=1)
testPredict_cnn = scaler.inverse_transform(testPredict_cnn)

testY_cnn = scaler.inverse_transform(testY)

# %%
trainScore_cnn = np.sqrt(mean_squared_error(trainY_cnn, trainPredict_cnn))
print('Train Score: %.2f RMSE' % (trainScore_cnn))
testScore_cnn = np.sqrt(mean_squared_error(testY_cnn, testPredict_cnn))
print('Test Score: %.2f RMSE' % (testScore_cnn))
# Out:
# Train Score: 0.12 RMSE
# Test Score: 0.12 RMSE

# %% [markdown]
# **e)**

# %% [markdown]
# #### RNN
#
# **Entrenamiento**

# %%
trainY_rnn = np.reshape(trainY_rnn, (trainY_rnn.shape[0], 1))
plt.plot(range(len(trainY_rnn)),trainY_rnn[:,0],label='original', linewidth=2)
plt.plot(range(len(trainY_rnn)),trainPredict_rnn[:,0],label='prediccion_rnn', linewidth=2)

plt.legend(['original','prediccion_rnn'])
plt.ylabel('Grados')
plt.xlabel('dias')
plt.grid(1)
plt.show()

# %% [markdown]
# **Prueba**

# %%
testY_rnn = np.reshape(testY_rnn, (testY_rnn.shape[0], 1))
plt.plot(range(len(testY_rnn)),testY_rnn[:,0],label='original', linewidth=2)
plt.plot(range(len(testY_rnn)),testPredict_rnn[:,0],label='prediccion_rnn', linewidth=2)

plt.legend(['original','prediccion_rnn'])
plt.ylabel('Grados')
plt.xlabel('Dias')
plt.grid(1)
plt.show()

# %% [markdown]
# #### CNN
# **Entrenamiento**

# %%
trainY_cnn = np.reshape(trainY_cnn, (trainY_cnn.shape[0], 1))
plt.plot(range(len(trainY_cnn)),trainY_cnn[:,0],label='original', linewidth=2)
plt.plot(range(len(trainY_cnn)),trainPredict_cnn[:,0],label='prediccion_cnn', linewidth=2)

plt.legend(['original','prediccion_cnn'])
plt.ylabel('Grados')
plt.xlabel('dias')
plt.grid(1)
plt.show()

# %% [markdown]
# **Prueba**

# %%
testY_cnn = np.reshape(testY_cnn, (testY_cnn.shape[0], 1))
plt.plot(range(len(testY_cnn)),testY_cnn[:,0],label='original', linewidth=2)
plt.plot(range(len(testY_cnn)),testPredict_cnn[:,0],label='prediccion_cnn', linewidth=2)

plt.legend(['original','prediccion_cnn'])
plt.ylabel('Grados')
plt.xlabel('Dias')
plt.grid(1)
plt.show()

# %% [markdown]
# Se puede ver que la predicción se comporta similar pero con valores mas acotados al original en ambas redes.

# %% [markdown]
# **f)**
# > f) En lugar de aumentar el número de dimensiones como el el paso c), entrene la red con un *timestep=lag* y con dimensión de entrada = 1. Compare y comente sobre el cambio de dimensiones y número de parámetros de las redes ¿Cuál tipo de red tiene más parámetros y porqué? ¿Se produce una mejora del error de entrenamiento y pruebas? ¿Los tiempos de computación son comparables? Comente brevemente sobre cuál es la forma correcta para aprovechar la información a través del tiempo, si con esta forma o la realizada en el paso e).

# %%
trainX, trainY = create_dataset(X_train_scaled, lag)
testX, testY = create_dataset(X_test_scaled, lag)
valX, valY = create_dataset(X_val_scaled, lag)

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
#valX = np.reshape(valX, (valX.shape[0], 1, valX.shape[1]))

# %%
lag = 1

model_rnn = Sequential()
model_rnn.add(SimpleRNN(units=4, input_shape=(lag,1), activation='tanh',return_sequences=False,go_backwards=False))
model_rnn.add(Dense(1,activation='linear'))
model_rnn.compile(loss='mean_squared_error', optimizer='adam')
results_rnn = model_rnn.fit(trainX, trainY, epochs=25, batch_size=1, verbose=1)
model_rnn.summary()
# Out:
# Epoch 1/25
# 11722/11722 [==============================] - 24s 2ms/step - loss: 1.0019
# Epoch 2/25
# 11722/11722 [==============================] - 23s 2ms/step - loss: 0.9990
# Epoch 3/25
# 11722/11722 [==============================] - 22s 2ms/step - loss: 0.9983
# Epoch 4/25
# 11722/11722 [==============================] - 21s 2ms/step - loss: 0.9985
# Epoch 5/25
# 11722/11722 [==============================] - 20s 2ms/step - loss: 0.9972
# Epoch 6/25
# 11722/11722 [==============================] - 20s 2ms/step - loss: 0.9973
# Epoch 7/25
# 11722/11722 [==============================] - 20s 2ms/step - loss: 0.9975
# Epoch 8/25
# 11722/11722 [==============================] - 20s 2ms/step - loss: 0.9962
# Epoch 9/25
# 11722/11722 [==============================] - 21s 2ms/step - loss: 0.9966
# Epoch 10/25
# 11722/11722 [==============================] - 20s 2ms/step - loss: 0.9964
# Epoch 11/25
# 11722/11722 [==============================] - 21s 2ms/step - loss: 0.9960
# Epoch 12/25
# 11722/11722 [==============================] - 22s 2ms/step - loss: 0.9954
# Epoch 13/25
# 11722/11722 [==============================] - 21s 2ms/step - loss: 0.9954
# Epoch 14/25
# 11722/11722 [==============================] - 19s 2ms/step - loss: 0.9959
# Epoch 15/25
# 11722/11722 [==============================] - 21s 2ms/step - loss: 0.9962
# Epoch 16/25
# 11722/11722 [==============================] - 24s 2ms/step - loss: 0.9961
# Epoch 17/25
# 11722/11722 [==============================] - 21s 2ms/step - loss: 0.9959
# Epoch 18/25
# 11722/11722 [==============================] - 20s 2ms/step - loss: 0.9954
# Epoch 19/25
# 11722/11722 [==============================] - 21s 2ms/step - loss: 0.9958
# Epoch 20/25
# 11722/11722 [==============================] - 19s 2ms/step - loss: 0.9962
# Epoch 21/25
# 11722/11722 [==============================] - 19s 2ms/step - loss: 0.9956
# Epoch 22/25
# 11722/11722 [==============================] - 25s 2ms/step - loss: 0.9959
# Epoch 23/25
# 11722/11722 [==============================] - 24s 2ms/step - loss: 0.9961
# Epoch 24/25
# 11722/11722 [==============================] - 23s 2ms/step - loss: 0.9959
# Epoch 25/25
# 11722/11722 [==============================] - 21s 2ms/step - loss: 0.9954
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_4 (SimpleRNN)     (None, 4)                 24
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________

# %%
listaloss  = []
for i in range(25):
    listaloss.append(results_rnn.history['loss'][i])

plt.plot(range(26)[1:],listaloss,label='loss', linewidth=2)

plt.legend(['loss_cnn'])
plt.ylabel('MSE')
plt.xlabel('epochs')
plt.grid(1)
plt.show()

# %%
model_cnn = Sequential()
model_cnn.add(Conv1D(4, kernel_size=2,input_shape=(lag,1), activation='relu',padding='valid')) # or kernel=2
model_cnn.add(Flatten())
model_cnn.add(Dense(1,activation='linear'))
model_cnn.compile(loss='mean_squared_error', optimizer='adam')
model_cnn.summary()
cnn_weights = model_cnn.get_weights()
hist_cnn = model_cnn.fit(trainX, trainY, epochs=25, batch_size=1, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1658   try:
# -> 1659     c_op = c_api.TF_FinishOperation(op_desc)
#    1660   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Negative dimension size caused by subtracting 2 from 1 for 'conv1d_10/convolution/Conv2D' (op: 'Conv2D') with input shapes: [?,1,1,1], [1,2,1,4].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-5343795f28d4> in <module>
#       1 model_cnn = Sequential()
# ----> 2 model_cnn.add(Conv1D(4, kernel_size=2,input_shape=(lag,1), activation='relu',padding='valid')) # or kernel=2
#       3 model_cnn.add(Flatten())
#       4 model_cnn.add(Dense(1,activation='linear'))
#       5 model_cnn.compile(loss='mean_squared_error', optimizer='adam')
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/keras/engine/sequential.py in add(self, layer)
#     163                     # and create the node connecting the current layer
#     164                     # to the input layer we just created.
# --> 165                     layer(x)
#     166                     set_inputs = True
#     167             else:
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     455             # Actually call the layer,
#     456             # collecting output(s), mask(s), and shape(s).
# --> 457             output = self.call(inputs, **kwargs)
#     458             output_mask = self.compute_mask(inputs, previous_mask)
#     459
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/keras/layers/convolutional.py in call(self, inputs)
#     161                 padding=self.padding,
#     162                 data_format=self.data_format,
# --> 163                 dilation_rate=self.dilation_rate[0])
#     164         if self.rank == 2:
#     165             outputs = K.conv2d(
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in conv1d(x, kernel, strides, padding, data_format, dilation_rate)
#    3609         strides=(strides,),
#    3610         padding=padding,
# -> 3611         data_format=tf_data_format)
#    3612
#    3613     if data_format == 'channels_first' and tf_data_format == 'NWC':
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in convolution(input, filter, padding, strides, dilation_rate, name, data_format)
#     849         name=name,
#     850         data_format=data_format)
# --> 851     return op(input, filter)
#     852
#     853
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in __call__(self, inp, filter)
#     964
#     965   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 966     return self.conv_op(inp, filter)
#     967
#     968
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in __call__(self, inp, filter)
#     589
#     590   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 591     return self.call(inp, filter)
#     592
#     593
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in __call__(self, inp, filter)
#     206         padding=self.padding,
#     207         data_format=self.data_format,
# --> 208         name=self.name)
#     209
#     210
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in _conv1d(self, input, filter, strides, padding, data_format, name)
#     195         padding=padding,
#     196         data_format=data_format,
# --> 197         name=name)
#     198
#     199   # pylint: enable=redefined-builtin
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     572                   func.__module__, arg_name, arg_value, 'in a future version'
#     573                   if date is None else ('after %s' % date), instructions)
# --> 574       return func(*args, **kwargs)
#     575
#     576     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     572                   func.__module__, arg_name, arg_value, 'in a future version'
#     573                   if date is None else ('after %s' % date), instructions)
# --> 574       return func(*args, **kwargs)
#     575
#     576     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in conv1d(value, filters, stride, padding, use_cudnn_on_gpu, data_format, name)
#    3480         padding,
#    3481         use_cudnn_on_gpu=use_cudnn_on_gpu,
# -> 3482         data_format=data_format)
#    3483     return array_ops.squeeze(result, [spatial_start_dim])
#    3484
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, data_format, dilations, name)
#    1024         "Conv2D", input=input, filter=filter, strides=strides,
#    1025                   padding=padding, use_cudnn_on_gpu=use_cudnn_on_gpu,
# -> 1026                   data_format=data_format, dilations=dilations, name=name)
#    1027   _result = _op.outputs[:]
#    1028   _inputs_flat = _op.inputs
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3298           input_types=input_types,
#    3299           original_op=self._default_original_op,
# -> 3300           op_def=op_def)
#    3301       self._create_op_helper(ret, compute_device=compute_device)
#    3302     return ret
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1821           op_def, inputs, node_def.attr)
#    1822       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1823                                 control_input_ops)
#    1824
#    1825     # Initialize self._outputs.
#
# ~/Documentos/Neuronales/neuroenv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1660   except errors.InvalidArgumentError as e:
#    1661     # Convert to ValueError for backwards compatibility.
# -> 1662     raise ValueError(str(e))
#    1663
#    1664   return c_op
#
# ValueError: Negative dimension size caused by subtracting 2 from 1 for 'conv1d_10/convolution/Conv2D' (op: 'Conv2D') with input shapes: [?,1,1,1], [1,2,1,4].

# %% [markdown]
# **g)**
# > g) Compare el desempeño de ambos modelos al variar el *lag* definido en c), recuerde que puede variarlo entre 1 y $T_{max}$. Comente brevemente sobre qué resulta mejor, el tener más información para predecir o si ésto satura la predicción por el efecto del gradiente desvaneciente ¿Ésto ocurre sólo con el modelo recurrente o con el convolucional también? ¿Por qué?

# %%
trainPredict_rnn = model_rnn.predict(trainX,batch_size=1)
trainPredict_rnn = scaler.inverse_transform(trainPredict_rnn)

trainY_rnn = scaler.inverse_transform(trainY)

testPredict_rnn = model_rnn.predict(testX,batch_size=1)
testPredict_rnn = scaler.inverse_transform(testPredict_rnn)

testY_rnn = scaler.inverse_transform(testY)

trainScore_rnn = np.sqrt(mean_squared_error(trainY_rnn, trainPredict_rnn))
print('Train Score: %.2f RMSE' % (trainScore_rnn))
testScore_rnn = np.sqrt(mean_squared_error(testY_rnn, testPredict_rnn))
print('Test Score: %.2f RMSE' % (testScore_rnn))
# Out:
# Train Score: 0.12 RMSE
# Test Score: 0.12 RMSE

# %% [markdown]
# El desempeño de esta red, respecto a la red entrenada en el apartado (c) no varia.

# %% [markdown]
# **h)**

# %% [markdown]
# **k)**

# %% [markdown]
# **i)**
